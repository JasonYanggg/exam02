# %% [markdown]
# # EE2405 Embedded System Lab Exam #2 Part 2
#
# **Please click on "Open in playground" at the upper-left corner to create a copy for you.**
#
# ---
#
# **Please fill in correct statements in the right of the codes to finish the scripts.**
# Data sample is generated with a quadratic function and we will train a regression model to fit the data.
# And we convert and interpret the trained model with a Tensorflow lite APIs.
#
# You can run the script again after you fill all the blank to check the outputs.
#
# ---
#
# The Method to Download the Jupyter Notebook:
# File > Download .ipynb

# %% [markdown]
# ## Import dependencies

# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf
# Numpy is a math library
import numpy as np
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# math is Python's math library
import math

# %% [markdown]
# ## Generate Data

# %%
# We'll generate this many sample datapoints
############################################################
#@markdown Please fill in the number of samples (the sample should be large enough, but not too large for computation).
SAMPLES =  1000#@param {type:"number"}
############################################################


############################################################
#@markdown Please fill in your student id, which is the random seed.
student_id = 106061233 #@param {type:"number"}
np.random.seed(student_id)
############################################################

# Generate a uniformly distributed set of random numbers
# in the range from 0 to 10
x_values = np.random.uniform(low=0, high=10, size=SAMPLES)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

############################################################
#@markdown Please fill in the statement to generate `y_values` with a quadratic function `y = x^2-5x+1`?
script = "y_values = np.array(x_values)**2 - 5 * x_values + 1" #@param {type:"string"}
exec(script)
############################################################

# Plot our data.
# The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Add some noise

# %%
# Add a small random number to each y value
y_values += np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Split our data

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Design a model

# %%
# We'll use Keras to create a simple model architecture
from tensorflow.keras import layers
model = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 16 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model.add(layers.Dense(16, activation='relu', input_shape=(1,)))

# The new second layer may help the network learn more complex representations
model.add(layers.Dense(16, activation='relu'))

# Final layer is a single neuron, since we want to output a single value
model.add(layers.Dense(1))

# Compile the model using a standard optimizer and loss function for regression
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ## Train the model

# %%
# Train the model on our training data while validating on our validation set
model.fit(x_train, y_train, epochs=1000, batch_size=16,
          validation_data=(x_validate, y_validate))

print("Done!")
# Out:
# Epoch 1/1000
# 38/38 [==============================] - 0s 6ms/step - loss: 310.4382 - mae: 12.0988 - val_loss: 363.4962 - val_mae: 13.0286
# Epoch 2/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 278.2489 - mae: 11.6558 - val_loss: 335.1655 - val_mae: 12.6248
# Epoch 3/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 254.8132 - mae: 11.1738 - val_loss: 297.8773 - val_mae: 12.1124
# Epoch 4/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 226.7185 - mae: 10.6686 - val_loss: 260.6112 - val_mae: 11.6633
# Epoch 5/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 195.8501 - mae: 10.1789 - val_loss: 224.5023 - val_mae: 11.2849
# Epoch 6/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 164.6617 - mae: 9.7874 - val_loss: 191.5501 - val_mae: 10.9790
# Epoch 7/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 142.5095 - mae: 9.4977 - val_loss: 164.8098 - val_mae: 10.7401
# Epoch 8/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 127.0871 - mae: 9.4135 - val_loss: 149.7157 - val_mae: 10.6011
# Epoch 9/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 120.9941 - mae: 9.4440 - val_loss: 140.5185 - val_mae: 10.5129
# Epoch 10/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 116.9523 - mae: 9.4562 - val_loss: 136.5363 - val_mae: 10.4210
# Epoch 11/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 115.3380 - mae: 9.4162 - val_loss: 134.5594 - val_mae: 10.3277
# Epoch 12/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 114.8992 - mae: 9.3369 - val_loss: 131.7708 - val_mae: 10.2409
# Epoch 13/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 110.9263 - mae: 9.2422 - val_loss: 129.6228 - val_mae: 10.1465
# Epoch 14/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 109.3624 - mae: 9.1673 - val_loss: 127.8022 - val_mae: 10.0643
# Epoch 15/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 107.5339 - mae: 9.0429 - val_loss: 125.1199 - val_mae: 9.9859
# Epoch 16/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 105.6544 - mae: 8.9967 - val_loss: 123.0628 - val_mae: 9.8887
# Epoch 17/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 103.9710 - mae: 8.9192 - val_loss: 121.9536 - val_mae: 9.7873
# Epoch 18/1000
# 38/38 [==============================] - 0s 2ms/step - loss:
1000
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0814 - mae: 1.1137 - val_loss: 2.5672 - val_mae: 1.1855
# Epoch 114/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0767 - mae: 1.1089 - val_loss: 2.5630 - val_mae: 1.1857
# Epoch 115/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0645 - mae: 1.0996 - val_loss: 2.7607 - val_mae: 1.2495
# Epoch 116/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 2.1038 - mae: 1.1014 - val_loss: 2.6723 - val_mae: 1.2212
# Epoch 117/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0483 - mae: 1.0973 - val_loss: 2.6296 - val_mae: 1.2021
# Epoch 118/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0224 - mae: 1.0876 - val_loss: 3.0959 - val_mae: 1.3592
# Epoch 119/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0318 - mae: 1.0925 - val_loss: 2.5297 - val_mae: 1.1689
# Epoch 120/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0178 - mae: 1.0790 - val_loss: 2.4975 - val_mae: 1.1549
# Epoch 121/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0561 - mae: 1.1006 - val_loss: 2.6754 - val_mae: 1.2260
# Epoch 122/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9863 - mae: 1.0790 - val_loss: 2.5418 - val_mae: 1.1679
# Epoch 123/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9958 - mae: 1.0811 - val_loss: 2.4864 - val_mae: 1.1544
# Epoch 124/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9707 - mae: 1.0859 - val_loss: 2.5797 - val_mae: 1.1940
# Epoch 125/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.9833 - mae: 1.0690 - val_loss: 2.4999 - val_mae: 1.1644
# Epoch 126/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.9624 - mae: 1.0748 - val_loss: 2.8653 - val_mae: 1.2918
# Epoch 127/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9397 - mae: 1.0706 - val_loss: 2.5037 - val_mae: 1.1644
# Epoch 128/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9597 - mae: 1.0684 - val_loss: 2.5020 - val_mae: 1.1659
# Epoch 129/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9744 - mae: 1.0684 - val_loss: 2.4341 - val_mae: 1.1286
# Epoch 130/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9240 - mae: 1.0646 - val_loss: 2.5162 - val_mae: 1.1735
# Epoch 131/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9099 - mae: 1.0596 - val_loss: 2.4290 - val_mae: 1.1243
# Epoch 132/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9400 - mae: 1.0689 - val_loss: 2.5558 - val_mae: 1.1693
# Epoch 133/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9486 - mae: 1.0585 - val_loss: 2.4205 - val_mae: 1.1190
# Epoch 134/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9379 - mae: 1.0599 - val_loss: 2.4161 - val_mae: 1.1186
# Epoch 135/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9031 - mae: 1.0578 - val_loss: 2.4327 - val_mae: 1.1405
# Epoch 136/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8755 - mae: 1.0468 - val_loss: 2.4043 - val_mae: 1.1260
# Epoch 137/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8791 - mae: 1.0442 - val_loss: 2.3924 - val_mae: 1.1101
# Epoch 138/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9571 - mae: 1.0519 - val_loss: 2.5336 - val_mae: 1.1845
# Epoch 139/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9437 - mae: 1.0639 - val_loss: 2.5148 - val_mae: 1.1530
# Epoch 140/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9374 - mae: 1.0455 - val_loss: 2.4300 - val_mae: 1.1426
# Epoch 141/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8842 - mae: 1.0446 - val_loss: 2.4246 - val_mae: 1.1193
# Epoch 142/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8609 - mae: 1.0325 - val_loss: 2.3560 - val_mae: 1.1067
# Epoch 143/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9003 - mae: 1.0438 - val_loss: 2.5142 - val_mae: 1.1538
# Epoch 144/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8748 - mae: 1.0397 - val_loss: 2.3572 - val_mae: 1.0967
# Epoch 145/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8328 - mae: 1.0260 - val_loss: 2.5016 - val_mae: 1.1497
# Epoch 146/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9584 - mae: 1.0325 - val_loss: 2.3891 - val_mae: 1.1057
# Epoch 147/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8585 - mae: 1.0284 - val_loss: 2.3528 - val_mae: 1.0932
# Epoch 148/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9142 - mae: 1.0397 - val_loss: 2.3815 - val_mae: 1.1239
# Epoch 149/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8231 - mae: 1.0219 - val_loss: 2.3465 - val_mae: 1.1051
# Epoch 150/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8285 - mae: 1.0197 - val_loss: 2.3150 - val_mae: 1.0917
# Epoch 151/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8374 - mae: 1.0230 - val_loss: 2.5194 - val_mae: 1.1615
# Epoch 152/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8328 - mae: 1.0180 - val_loss: 2.3294 - val_mae: 1.0851
# Epoch 153/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.8228 - mae: 1.0090 - val_loss: 2.3410 - val_mae: 1.0896
# Epoch 154/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8210 - mae: 1.0214 - val_loss: 2.3169 - val_mae: 1.0949
# Epoch 155/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8542 - mae: 1.0246 - val_loss: 2.3068 - val_mae: 1.0921
# Epoch 156/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8126 - mae: 1.0116 - val_loss: 2.7264 - val_mae: 1.2433
# Epoch 157/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.8326 - mae: 1.0169 - val_loss: 2.2855 - val_mae: 1.0790
# Epoch 158/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8263 - mae: 1.0182 - val_loss: 2.2857 - val_mae: 1.0769
# Epoch 159/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8098 - mae: 1.0126 - val_loss: 2.2970 - val_mae: 1.0905
# Epoch 160/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8000 - mae: 1.0043 - val_loss: 2.2804 - val_mae: 1.0818
# Epoch 161/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8307 - mae: 1.0079 - val_loss: 2.9031 - val_mae: 1.3062
# Epoch 162/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8503 - mae: 1.0224 - val_loss: 2.2736 - val_mae: 1.0793
# Epoch 163/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8205 - mae: 1.0115 - val_loss: 2.2696 - val_mae: 1.0773
# Epoch 164/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8385 - mae: 1.0195 - val_loss: 2.2945 - val_mae: 1.0947
# Epoch 165/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7756 - mae: 0.9960 - val_loss: 2.3485 - val_mae: 1.0982
# Epoch 166/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8307 - mae: 1.0126 - val_loss: 2.2616 - val_mae: 1.0757
# Epoch 167/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7768 - mae: 1.0024 - val_loss: 2.4135 - val_mae: 1.1474
# Epoch 168/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8161 - mae: 1.0170 - val_loss: 2.4529 - val_mae: 1.1621
# Epoch 169/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8183 - mae: 1.0098 - val_loss: 2.2514 - val_mae: 1.0700
# Epoch 170/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8007 - mae: 1.0070 - val_loss: 2.2860 - val_mae: 1.0897
# Epoch 171/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7904 - mae: 1.0064 - val_loss: 2.3132 - val_mae: 1.0894
# Epoch 172/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7998 - mae: 1.0081 - val_loss: 2.4191 - val_mae: 1.1348
# Epoch 173/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7897 - mae: 1.0042 - val_loss: 2.2886 - val_mae: 1.0989
# Epoch 174/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7698 - mae: 1.0014 - val_loss: 2.3503 - val_mae: 1.1077
# Epoch 175/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.7852 - mae: 0.9970 - val_loss: 2.2937 - val_mae: 1.0980
# Epoch 176/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7993 - mae: 1.0019 - val_loss: 2.2693 - val_mae: 1.0937
# Epoch 177/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7956 - mae: 1.0100 - val_loss: 2.2391 - val_mae: 1.0718
# Epoch 178/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7899 - mae: 1.0083 - val_loss: 2.2436 - val_mae: 1.0793
# Epoch 179/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7509 - mae: 0.9896 - val_loss: 2.2619 - val_mae: 1.0915
# Epoch 180/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8108 - mae: 1.0086 - val_loss: 2.3297 - val_mae: 1.1058
# Epoch 181/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7580 - mae: 1.0000 - val_loss: 2.3289 - val_mae: 1.1040
# Epoch 182/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8025 - mae: 0.9950 - val_loss: 2.3710 - val_mae: 1.1229
# Epoch 183/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.7341 - mae: 0.9876 - val_loss: 2.2230 - val_mae: 1.0687
# Epoch 184/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8152 - mae: 1.0024 - val_loss: 2.2170 - val_mae: 1.0636
# Epoch 185/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7864 - mae: 1.0032 - val_loss: 2.2122 - val_mae: 1.0675
# Epoch 186/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7783 - mae: 0.9959 - val_loss: 2.2447 - val_mae: 1.0874
# Epoch 187/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8019 - mae: 1.0007 - val_loss: 2.3119 - val_mae: 1.1015
# Epoch 188/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7380 - mae: 0.9942 - val_loss: 2.2119 - val_mae: 1.0648
# Epoch 189/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7688 - mae: 0.9982 - val_loss: 2.2051 - val_mae: 1.0668
# Epoch 190/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7635 - mae: 1.0011 - val_loss: 2.3329 - val_mae: 1.1293
# Epoch 191/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7926 - mae: 0.9928 - val_loss: 2.2093 - val_mae: 1.0754
# Epoch 192/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7842 - mae: 0.9802 - val_loss: 2.2131 - val_mae: 1.0761
# Epoch 193/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7317 - mae: 0.9923 - val_loss: 2.2297 - val_mae: 1.0768
# Epoch 194/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7562 - mae: 0.9851 - val_loss: 2.2651 - val_mae: 1.0898
# Epoch 195/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7530 - mae: 0.9955 - val_loss: 2.5665 - val_mae: 1.2043
# Epoch 196/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7695 - mae: 0.9884 - val_loss: 2.2894 - val_mae: 1.1154
# Epoch 197/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7404 - mae: 0.9915 - val_loss: 2.2202 - val_mae: 1.0740
# Epoch 198/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7215 - mae: 0.9824 - val_loss: 2.2204 - val_mae: 1.0843
# Epoch 199/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7377 - mae: 1.0021 - val_loss: 2.2104 - val_mae: 1.0891
# Epoch 200/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7352 - mae: 0.9854 - val_loss: 2.1948 - val_mae: 1.0837
# Epoch 201/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7050 - mae: 0.9823 - val_loss: 2.1693 - val_mae: 1.0552
# Epoch 202/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7093 - mae: 0.9881 - val_loss: 2.1592 - val_mae: 1.0592
# Epoch 203/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7148 - mae: 0.9824 - val_loss: 2.5858 - val_mae: 1.2180
# Epoch 204/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7205 - mae: 0.9886 - val_loss: 2.1514 - val_mae: 1.0561
# Epoch 205/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.6609 - mae: 0.9726 - val_loss: 2.2046 - val_mae: 1.0769
# Epoch 206/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6966 - mae: 0.9819 - val_loss: 2.2386 - val_mae: 1.0904
# Epoch 207/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7258 - mae: 0.9842 - val_loss: 2.2456 - val_mae: 1.0937
# Epoch 208/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7093 - mae: 0.9878 - val_loss: 2.1563 - val_mae: 1.0608
# Epoch 209/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7165 - mae: 0.9828 - val_loss: 2.1739 - val_mae: 1.0792
# Epoch 210/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6946 - mae: 0.9774 - val_loss: 2.1950 - val_mae: 1.0761
# Epoch 211/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6821 - mae: 0.9732 - val_loss: 2.3143 - val_mae: 1.1345
# Epoch 212/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.
1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2785 - mae: 0.8800 - val_loss: 1.5379 - val_mae: 0.9757
# Epoch 345/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2257 - mae: 0.8624 - val_loss: 1.5208 - val_mae: 0.9591
# Epoch 346/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2787 - mae: 0.8763 - val_loss: 1.5618 - val_mae: 0.9894
# Epoch 347/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2369 - mae: 0.8680 - val_loss: 1.4858 - val_mae: 0.9453
# Epoch 348/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2370 - mae: 0.8655 - val_loss: 1.6024 - val_mae: 1.0041
# Epoch 349/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2810 - mae: 0.8707 - val_loss: 1.9786 - val_mae: 1.1227
# Epoch 350/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2390 - mae: 0.8746 - val_loss: 1.5014 - val_mae: 0.9545
# Epoch 351/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.2760 - mae: 0.8826 - val_loss: 1.4822 - val_mae: 0.9482
# Epoch 352/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2412 - mae: 0.8673 - val_loss: 1.7633 - val_mae: 1.0604
# Epoch 353/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2708 - mae: 0.8721 - val_loss: 1.4783 - val_mae: 0.9435
# Epoch 354/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2448 - mae: 0.8761 - val_loss: 1.4932 - val_mae: 0.9628
# Epoch 355/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2327 - mae: 0.8749 - val_loss: 1.4612 - val_mae: 0.9445
# Epoch 356/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2283 - mae: 0.8709 - val_loss: 1.5477 - val_mae: 0.9760
# Epoch 357/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2489 - mae: 0.8667 - val_loss: 1.5798 - val_mae: 1.0054
# Epoch 358/1000
# ...
# Epoch 882/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0283 - mae: 0.8007 - val_loss: 1.9548 - val_mae: 1.1524
# Epoch 883/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0846 - mae: 0.8228 - val_loss: 1.1004 - val_mae: 0.8639
# Epoch 884/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0746 - mae: 0.8150 - val_loss: 1.0861 - val_mae: 0.8676
# Epoch 885/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0383 - mae: 0.8100 - val_loss: 1.2446 - val_mae: 0.9319
# Epoch 886/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0524 - mae: 0.8099 - val_loss: 1.0769 - val_mae: 0.8636
# Epoch 887/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0323 - mae: 0.7923 - val_loss: 1.1133 - val_mae: 0.8797
# Epoch 888/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0741 - mae: 0.8190 - val_loss: 1.2612 - val_mae: 0.9349
# Epoch 889/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0522 - mae: 0.8151 - val_loss: 1.2270 - val_mae: 0.9132
# Epoch 890/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0711 - mae: 0.8142 - val_loss: 1.0916 - val_mae: 0.8726
# Epoch 891/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0487 - mae: 0.8101 - val_loss: 1.1238 - val_mae: 0.8882
# Epoch 892/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0676 - mae: 0.8097 - val_loss: 1.0719 - val_mae: 0.8510
# Epoch 893/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0454 - mae: 0.8102 - val_loss: 1.1037 - val_mae: 0.8658
# Epoch 894/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0669 - mae: 0.8073 - val_loss: 1.1194 - val_mae: 0.8722
# Epoch 895/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0588 - mae: 0.8052 - val_loss: 1.0694 - val_mae: 0.8542
# Epoch 896/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0328 - mae: 0.8019 - val_loss: 1.1227 - val_mae: 0.8792
# Epoch 897/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0729 - mae: 0.8095 - val_loss: 1.2689 - val_mae: 0.9359
# Epoch 898/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0475 - mae: 0.8211 - val_loss: 1.3139 - val_mae: 0.9437
# Epoch 899/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0612 - mae: 0.8125 - val_loss: 1.5494 - val_mae: 1.0261
# Epoch 900/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0656 - mae: 0.8125 - val_loss: 1.1153 - val_mae: 0.8708
# Epoch 901/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0572 - mae: 0.8056 - val_loss: 1.1900 - val_mae: 0.8988
# Epoch 902/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0632 - mae: 0.8238 - val_loss: 1.0680 - val_mae: 0.8539
# Epoch 903/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0244 - mae: 0.7971 - val_loss: 1.0676 - val_mae: 0.8530
# Epoch 904/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0761 - mae: 0.8179 - val_loss: 1.0715 - val_mae: 0.8531
# Epoch 905/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0415 - mae: 0.8017 - val_loss: 1.0939 - val_mae: 0.8621
# Epoch 906/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0406 - mae: 0.8074 - val_loss: 1.0701 - val_mae: 0.8544
# Epoch 907/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0632 - mae: 0.8166 - val_loss: 1.1098 - val_mae: 0.8689
# Epoch 908/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0409 - mae: 0.7992 - val_loss: 1.0737 - val_mae: 0.8555
# Epoch 909/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0598 - mae: 0.8099 - val_loss: 1.0854 - val_mae: 0.8683
# Epoch 910/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0341 - mae: 0.8029 - val_loss: 1.1503 - val_mae: 0.8844
# Epoch 911/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0603 - mae: 0.8087 - val_loss: 1.1996 - val_mae: 0.9027
# Epoch 912/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0432 - mae: 0.8056 - val_loss: 1.1517 - val_mae: 0.8968
# Epoch 913/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0359 - mae: 0.8189 - val_loss: 1.3406 - val_mae: 0.9544
# Epoch 914/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0478 - mae: 0.8054 - val_loss: 1.2778 - val_mae: 0.9443
# Epoch 915/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0590 - mae: 0.8032 - val_loss: 1.0936 - val_mae: 0.8613
# Epoch 916/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0483 - mae: 0.8187 - val_loss: 1.0933 - val_mae: 0.8622
# Epoch 917/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0568 - mae: 0.8069 - val_loss: 1.0962 - val_mae: 0.8747
# Epoch 918/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0718 - mae: 0.8053 - val_loss: 1.1710 - val_mae: 0.9045
# Epoch 919/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0409 - mae: 0.8030 - val_loss: 1.2269 - val_mae: 0.9269
# Epoch 920/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0462 - mae: 0.8170 - val_loss: 1.0806 - val_mae: 0.8552
# Epoch 921/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0393 - mae: 0.8076 - val_loss: 1.2066 - val_mae: 0.9180
# Epoch 922/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0369 - mae: 0.8048 - val_loss: 1.1070 - val_mae: 0.8680
# Epoch 923/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0829 - mae: 0.8139 - val_loss: 1.1063 - val_mae: 0.8796
# Epoch 924/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0267 - mae: 0.7946 - val_loss: 1.1827 - val_mae: 0.9102
# Epoch 925/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0705 - mae: 0.8202 - val_loss: 1.1657 - val_mae: 0.8907
# Epoch 926/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0385 - mae: 0.8124 - val_loss: 1.3671 - val_mae: 0.9636
# Epoch 927/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0475 - mae: 0.8002 - val_loss: 1.0610 - val_mae: 0.8481
# Epoch 928/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0581 - mae: 0.8148 - val_loss: 1.0677 - val_mae: 0.8561
# Epoch 929/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0474 - mae: 0.8082 - val_loss: 1.0824 - val_mae: 0.8573
# Epoch 930/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0430 - mae: 0.8079 - val_loss: 1.2879 - val_mae: 0.9348
# Epoch 931/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0706 - mae: 0.8185 - val_loss: 1.0609 - val_mae: 0.8519
# Epoch 932/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0427 - mae: 0.8074 - val_loss: 1.0944 - val_mae: 0.8613
# Epoch 933/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0501 - mae: 0.8134 - val_loss: 1.1253 - val_mae: 0.8755
# Epoch 934/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0387 - mae: 0.8064 - val_loss: 1.4101 - val_mae: 0.9784
# Epoch 935/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0913 - mae: 0.8275 - val_loss: 1.0902 - val_mae: 0.8711
# Epoch 936/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0111 - mae: 0.8018 - val_loss: 1.0770 - val_mae: 0.8476
# Epoch 937/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0901 - mae: 0.8156 - val_loss: 1.0981 - val_mae: 0.8635
# Epoch 938/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0396 - mae: 0.8045 - val_loss: 1.2404 - val_mae: 0.9167
# Epoch 939/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0548 - mae: 0.8101 - val_loss: 1.1516 - val_mae: 0.8861
# Epoch 940/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0553 - mae: 0.8053 - val_loss: 1.0624 - val_mae: 0.8547
# Epoch 941/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0484 - mae: 0.8130 - val_loss: 1.0641 - val_mae: 0.8461
# Epoch 942/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0350 - mae: 0.8130 - val_loss: 1.0638 - val_mae: 0.8559
# Epoch 943/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0536 - mae: 0.7967 - val_loss: 1.0587 - val_mae: 0.8529
# Epoch 944/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0784 - mae: 0.8129 - val_loss: 1.8544 - val_mae: 1.1230
# Epoch 945/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0441 - mae: 0.8098 - val_loss: 1.0606 - val_mae: 0.8531
# Epoch 946/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0456 - mae: 0.8013 - val_loss: 1.1309 - val_mae: 0.8780
# Epoch 947/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0465 - mae: 0.8072 - val_loss: 1.1564 - val_mae: 0.8979
# Epoch 948/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0557 - mae: 0.8062 - val_loss: 1.2933 - val_mae: 0.9373
# Epoch 949/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0431 - mae: 0.8092 - val_loss: 1.0986 - val_mae: 0.8747
# Epoch 950/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0689 - mae: 0.8266 - val_loss: 1.2805 - val_mae: 0.9322
# Epoch 951/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0618 - mae: 0.8144 - val_loss: 1.0620 - val_mae: 0.8533
# Epoch 952/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0399 - mae: 0.8079 - val_loss: 1.0667 - val_mae: 0.8595
# Epoch 953/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0362 - mae: 0.8019 - val_loss: 1.0730 - val_mae: 0.8519
# Epoch 954/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0780 - mae: 0.8076 - val_loss: 1.1231 - val_mae: 0.8835
# Epoch 955/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0327 - mae: 0.8073 - val_loss: 1.0567 - val_mae: 0.8528
# Epoch 956/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0490 - mae: 0.8021 - val_loss: 1.5284 - val_mae: 1.0191
# Epoch 957/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0918 - mae: 0.8225 - val_loss: 1.0578 - val_mae: 0.8525
# Epoch 958/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0683 - mae: 0.8102 - val_loss: 1.2790 - val_mae: 0.9315
# Epoch 959/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0616 - mae: 0.8132 - val_loss: 1.2766 - val_mae: 0.9306
# Epoch 960/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0417 - mae: 0.8010 - val_loss: 1.0570 - val_mae: 0.8506
# Epoch 961/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0224 - mae: 0.8091 - val_loss: 1.0556 - val_mae: 0.8519
# Epoch 962/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0485 - mae: 0.8054 - val_loss: 1.1090 - val_mae: 0.8695
# Epoch 963/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0550 - mae: 0.8088 - val_loss: 1.0694 - val_mae: 0.8525
# Epoch 964/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0525 - mae: 0.8128 - val_loss: 1.3219 - val_mae: 0.9480
# Epoch 965/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0469 - mae: 0.8085 - val_loss: 1.0760 - val_mae: 0.8555
# Epoch 966/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0092 - mae: 0.7961 - val_loss: 1.0565 - val_mae: 0.8491
# Epoch 967/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0525 - mae: 0.8075 - val_loss: 1.0634 - val_mae: 0.8561
# Epoch 968/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0682 - mae: 0.8144 - val_loss: 1.0570 - val_mae: 0.8532
# Epoch 969/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0505 - mae: 0.8084 - val_loss: 1.0977 - val_mae: 0.8708
# Epoch 970/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0353 - mae: 0.8053 - val_loss: 1.1915 - val_mae: 0.9110
# Epoch 971/1000
# 38/38 [==============================] - 0s 7ms/step - loss: 1.0374 - mae: 0.8034 - val_loss: 1.0600 - val_mae: 0.8542
# Epoch 972/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0731 - mae: 0.8050 - val_loss: 1.2403 - val_mae: 0.9344
# Epoch 973/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0590 - mae: 0.8173 - val_loss: 1.0813 - val_mae: 0.8638
# Epoch 974/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0708 - mae: 0.8121 - val_loss: 1.0955 - val_mae: 0.8742
# Epoch 975/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0719 - mae: 0.8144 - val_loss: 1.3421 - val_mae: 0.9609
# Epoch 976/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0677 - mae: 0.8174 - val_loss: 1.0678 - val_mae: 0.8552
# Epoch 977/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0389 - mae: 0.8063 - val_loss: 1.1797 - val_mae: 0.9037
# Epoch 978/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0403 - mae: 0.8115 - val_loss: 1.0681 - val_mae: 0.8503
# Epoch 979/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0703 - mae: 0.8139 - val_loss: 1.0738 - val_mae: 0.8546
# Epoch 980/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0458 - mae: 0.8132 - val_loss: 1.0691 - val_mae: 0.8516
# Epoch 981/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0405 - mae: 0.8061 - val_loss: 1.0780 - val_mae: 0.8663
# Epoch 982/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0485 - mae: 0.8089 - val_loss: 1.1070 - val_mae: 0.8686
# Epoch 983/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0439 - mae: 0.8114 - val_loss: 1.3554 - val_mae: 0.9593
# Epoch 984/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0556 - mae: 0.8164 - val_loss: 1.1111 - val_mae: 0.8699
# Epoch 985/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0252 - mae: 0.8000 - val_loss: 1.0860 - val_mae: 0.8586
# Epoch 986/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0585 - mae: 0.8046 - val_loss: 1.0610 - val_mae: 0.8595
# Epoch 987/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0557 - mae: 0.8050 - val_loss: 1.7706 - val_mae: 1.0998
# Epoch 988/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0592 - mae: 0.8106 - val_loss: 1.1379 - val_mae: 0.8969
# Epoch 989/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0313 - mae: 0.8044 - val_loss: 1.1807 - val_mae: 0.9083
# Epoch 990/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0344 - mae: 0.8033 - val_loss: 1.1188 - val_mae: 0.8740
# Epoch 991/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0547 - mae: 0.8066 - val_loss: 1.0582 - val_mae: 0.8496
# Epoch 992/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0455 - mae: 0.8108 - val_loss: 1.1722 - val_mae: 0.9036
# Epoch 993/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0433 - mae: 0.8097 - val_loss: 1.0552 - val_mae: 0.8501
# Epoch 994/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0462 - mae: 0.8089 - val_loss: 1.0593 - val_mae: 0.8578
# Epoch 995/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0340 - mae: 0.8089 - val_loss: 1.1722 - val_mae: 0.9073
# Epoch 996/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0447 - mae: 0.8109 - val_loss: 1.0655 - val_mae: 0.8598
# Epoch 997/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0398 - mae: 0.8069 - val_loss: 1.2628 - val_mae: 0.9262
# Epoch 998/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0343 - mae: 0.8038 - val_loss: 1.1450 - val_mae: 0.8838
# Epoch 999/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0722 - mae: 0.8124 - val_loss: 1.0562 - val_mae: 0.8538
# Epoch 1000/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0401 - mae: 0.8127 - val_loss: 1.0786 - val_mae: 0.8563
# Done!

# %% [markdown]
# ## Convert the Tensorflow Model to Tensorflow Lite Model

# %%
# Convert the model to the TensorFlow Lite format with quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)
# Out:
# 2532

# %% [markdown]
# ## Predict

# %% [markdown]
# ### Predict with Tensorflow Model

# %%
# Use the model to make predictions from our test data

############################################################
#@markdown How to use the model to predict the result with the test data (`x_test`) and save the result in a variable `predictions`?
script = "predictions = model.predict(x_test)" #@param {type:"string"}
exec(script)
############################################################

# %% [markdown]
# ### Predict with Tensorflow Lite Model

# %%
# Use the Tensorflow lite model to make interfences from our test data
#@markdown Please choose and fill in correct code statements from one of the following:
#@markdown 1. interpreter.invoke() 
#@markdown 2. interpreter_input().fill(x_test[i])
#@markdown 3. interpreter = tf.lite.Interpreter('model.tflite')
#@markdown 4. interpreter_predictions[i] = interpreter_output()[0]
#@markdown 5. interpreter_output = interpreter.tensor(interpreter.get_output_details()[0]["index"])
#@markdown 6. interpreter_input = interpreter.tensor(interpreter.get_input_details()[0]["index"])

############################################################
# Instantiate an interpreter for the TFLite model
#@markdown Which is the statement to instantiate an interpreter with a TFLite Model named `model.tflite`?
script_1 = "interpreter = tf.lite.Interpreter('model.tflite')" #@param {type:"string"}
exec(script_1)
############################################################

# Allocate memory for the model
interpreter.allocate_tensors()

############################################################
# Get the input tensors so we can feed in values 
#@markdown Which is the statement to get input sensors?
script_2 = "interpreter_input = interpreter.tensor(interpreter.get_input_details()[0][\"index\"])" #@param {type:"string"}
exec(script_2)
############################################################

############################################################
# Get the output tensors so we can get the results
#@markdown Which is the statement to get output sensors?
script_3 = "interpreter_output = interpreter.tensor(interpreter.get_output_details()[0][\"index\"])" #@param {type:"string"}
exec(script_3)
############################################################

# Create arrays to store the results
interpreter_predictions = np.empty(x_test.size)

# Run each model's interpreter for each value and store the results in arrays
for i in range(x_test.size):
  ############################################################
  #@markdown Which is the statement to fill the input of the interpreter with `x_test[i]`?
  script_4 = "interpreter_input().fill(x_test[i])" #@param {type:"string"}
  exec(script_4)
  ############################################################
  ############################################################
  #@markdown Which is the statement to invoke the interpreter?
  script_5 = "interpreter.invoke() " #@param {type:"string"}
  exec(script_5)
  ############################################################
  ############################################################
  #@markdown Which is the statement to get the output from the interpreter and save the output in `interpreter_predictions[i]`?
  script_6 = "interpreter_predictions[i] = interpreter_output()[0]"#@param {type:"string"}
  exec(script_6)
  ############################################################


# Make the shape of the y_test be the same as the predictions
y_test = np.reshape(y_test, predictions.shape)
# Make the shape of the interpreter_predictions be the same as the predictions
interpreter_predictions = np.reshape(interpreter_predictions, predictions.shape)

# %% [markdown]
# ## Plot the Result

# %%
plt.clf()
plt.title('Test data predicted vs actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted (tensorflow)')
############################################################
#@markdown Please write the statement to plot the outputs in green dots with a label `Predicted (tflite)` from the interpreter.
script = "plt.plot(x_test, interpreter_predictions, 'g.', label='Predicted (tflite)')"#@param {type:"string"}
exec(script)
############################################################
plt.legend()
plt.show()
